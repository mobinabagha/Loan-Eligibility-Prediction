# %%
import matplotlib.pyplot as plt
import pandas as pd

# Define the summary table data
data = {
    "Step": [
        "Data Preprocessing", 
        "Feature Engineering", 
        "Feature Selection", 
        "Model Training", 
        "Evaluation", 
        "Tuning", 
        "Deployment"
    ],
    "Purpose": [
        "Clean, transform, and scale data", 
        "Improve input features", 
        "Reduce dimensionality", 
        "Fit model to data", 
        "Measure model performance", 
        "Optimize hyperparameters", 
        "Export and serve model"
    ],
    "Tools": [
        "Scikit-learn preprocessors", 
        "Custom logic, sklearn", 
        "SelectKBest, PCA", 
        "SVM, RandomForest, etc.", 
        "accuracy_score, etc.", 
        "GridSearchCV", 
        "joblib, Flask, FastAPI"
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Plot the table
fig, ax = plt.subplots(figsize=(12, 4))
ax.axis('off')
table = ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')
table.auto_set_font_size(False)
table.set_fontsize(12)
table.scale(1, 2)

# Save as PDF
plt.tight_layout()
plt.savefig("ml_pipeline_summary_table.pdf")
plt.show()
